# %%
#importing the libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM , Dense,GlobalMaxPooling1D,Flatten
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# %%
#importing the dataset
with open('content.json') as content:
  data1 = json.load(content)
#getting all the data to lists
tags = []
inputs = []
responses={}
for intent in data1['intents']:
  responses[intent['tag']]=intent['responses']
  for lines in intent['input']:
    inputs.append(lines)
    tags.append(intent['tag'])
#converting to dataframe
data = pd.DataFrame({"inputs":inputs,
                     "tags":tags})
print(data)
# Out:
#                                           inputs           tags
# 0                                          hello       greeting
# 1                                       hi there       greeting
# 2                               nice to meet you       greeting
# 3       hi, is this is the pirate's organization       greeting
# 4                             any pirates here ?       greeting
# ..                                           ...            ...
# 76         tell me more about the pre requisites  prerequisites
# 77    give more details about the pre-requisites  prerequisites
# 78                     What are the requirements  prerequisites
# 79                 what's the basic requirements  prerequisites
# 80  what are the basic skills to get recruited ?  prerequisites
#
# [81 rows x 2 columns]

# %%
#removing punctuations
import string
data['inputs'] = data['inputs'].apply(lambda wrd:[ltrs.lower() for ltrs in wrd if ltrs not in string.punctuation])
data['inputs'] = data['inputs'].apply(lambda wrd: ''.join(wrd))
#tokenize the data
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(data['inputs'])
train = tokenizer.texts_to_sequences(data['inputs'])

#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['tags'])

# %%
#input length
input_shape = x_train.shape[1]
print(input_shape)
#define vocabulary
vocabulary = len(tokenizer.word_index)
print("number of unique words : ",vocabulary)
#output length
output_length = le.classes_.shape[0]
print("output length: ",output_length)
# Out:
# 8
# number of unique words :  96
# output length:  8

# %%
#creating the model
i = Input(shape=(input_shape,))
x = Embedding(vocabulary+1,10)(i)
x = LSTM(10,return_sequences=True)(x)
x = Flatten()(x)
x = Dense(output_length,activation="softmax")(x)
model  = Model(i,x)
#compiling the model
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])
#training the model
train = model.fit(x_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 2s 9ms/step - loss: 2.0833 - accuracy: 0.0494
# Epoch 2/200
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0801 - accuracy: 0.0123
# Epoch 3/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0765 - accuracy: 0.0741
# Epoch 4/200
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0737 - accuracy: 0.1605
# Epoch 5/200
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0710 - accuracy: 0.1975
# Epoch 6/200
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0679 - accuracy: 0.2099
# Epoch 7/200
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0645 - accuracy: 0.2099
# Epoch 8/200
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0613 - accuracy: 0.2099
# Epoch 9/200
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0578 - accuracy: 0.2222
# Epoch 10/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0536 - accuracy: 0.2222
# Epoch 11/200
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0497 - accuracy: 0.2222
# Epoch 12/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0448 - accuracy: 0.2346
# Epoch 13/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0395 - accuracy: 0.2346
# Epoch 14/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0338 - accuracy: 0.2346
# Epoch 15/200
# 3/3 [==============================] - 0s 9ms/step - loss: 2.0274 - accuracy: 0.2346
# Epoch 16/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0203 - accuracy: 0.2346
# Epoch 17/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0120 - accuracy: 0.2346
# Epoch 18/200
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0039 - accuracy: 0.2346
# Epoch 19/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9936 - accuracy: 0.2469
# Epoch 20/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9824 - accuracy: 0.2346
# Epoch 21/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.9707 - accuracy: 0.2346
# Epoch 22/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9565 - accuracy: 0.2346
# Epoch 23/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9419 - accuracy: 0.2346
# Epoch 24/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9266 - accuracy: 0.2346
# Epoch 25/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9101 - accuracy: 0.2346
# Epoch 26/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8904 - accuracy: 0.2469
# Epoch 27/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8704 - accuracy: 0.2469
# Epoch 28/200
# 3/3 [==============================] - 0s 8ms/step - loss: 1.8505 - accuracy: 0.3086
# Epoch 29/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8282 - accuracy: 0.3457
# Epoch 30/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8059 - accuracy: 0.3951
# Epoch 31/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7807 - accuracy: 0.4568
# Epoch 32/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7580 - accuracy: 0.4568
# Epoch 33/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7297 - accuracy: 0.4568
# Epoch 34/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7038 - accuracy: 0.4321
# Epoch 35/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6767 - accuracy: 0.4568
# Epoch 36/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6477 - accuracy: 0.4321
# Epoch 37/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6171 - accuracy: 0.4321
# Epoch 38/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5883 - accuracy: 0.4444
# Epoch 39/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5571 - accuracy: 0.4444
# Epoch 40/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.5262 - accuracy: 0.4691
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4941 - accuracy: 0.4938
# Epoch 42/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4642 - accuracy: 0.5432
# Epoch 43/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4352 - accuracy: 0.5556
# Epoch 44/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4040 - accuracy: 0.5556
# Epoch 45/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3726 - accuracy: 0.5556
# Epoch 46/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3423 - accuracy: 0.5309
# Epoch 47/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3146 - accuracy: 0.5309
# Epoch 48/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2869 - accuracy: 0.5432
# Epoch 49/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2587 - accuracy: 0.5432
# Epoch 50/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2288 - accuracy: 0.5556
# Epoch 51/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2010 - accuracy: 0.5679
# Epoch 52/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1732 - accuracy: 0.5802
# Epoch 53/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1472 - accuracy: 0.6173
# Epoch 54/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1216 - accuracy: 0.6296
# Epoch 55/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0965 - accuracy: 0.6543
# Epoch 56/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0719 - accuracy: 0.6543
# Epoch 57/200
# 3/3 [==============================] - 0s 9ms/step - loss: 1.0471 - accuracy: 0.6543
# Epoch 58/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0227 - accuracy: 0.6667
# Epoch 59/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9989 - accuracy: 0.6790
# Epoch 60/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9771 - accuracy: 0.6914
# Epoch 61/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9531 - accuracy: 0.6914
# Epoch 62/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9350 - accuracy: 0.7407
# Epoch 63/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9112 - accuracy: 0.7407
# Epoch 64/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8864 - accuracy: 0.7407
# Epoch 65/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8653 - accuracy: 0.7531
# Epoch 66/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8450 - accuracy: 0.7531
# Epoch 67/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8230 - accuracy: 0.7778
# Epoch 68/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8027 - accuracy: 0.7778
# Epoch 69/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7830 - accuracy: 0.7901
# Epoch 70/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7654 - accuracy: 0.8025
# Epoch 71/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7462 - accuracy: 0.8025
# Epoch 72/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7222 - accuracy: 0.8148
# Epoch 73/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7031 - accuracy: 0.8148
# Epoch 74/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6847 - accuracy: 0.8395
# Epoch 75/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6656 - accuracy: 0.8395
# Epoch 76/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6472 - accuracy: 0.8395
# Epoch 77/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6301 - accuracy: 0.8395
# Epoch 78/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6128 - accuracy: 0.8395
# Epoch 79/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5966 - accuracy: 0.8889
# Epoch 80/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5804 - accuracy: 0.8889
# Epoch 81/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5653 - accuracy: 0.8889
# Epoch 82/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5497 - accuracy: 0.8889
# Epoch 83/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5370 - accuracy: 0.8889
# Epoch 84/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5215 - accuracy: 0.8889
# Epoch 85/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5073 - accuracy: 0.8889
# Epoch 86/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4944 - accuracy: 0.8889
# Epoch 87/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4817 - accuracy: 0.8889
# Epoch 88/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4700 - accuracy: 0.8889
# Epoch 89/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4568 - accuracy: 0.8889
# Epoch 90/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.9012
# Epoch 91/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4343 - accuracy: 0.9136
# Epoch 92/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4230 - accuracy: 0.9259
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4129 - accuracy: 0.9259
# Epoch 94/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4029 - accuracy: 0.9259
# Epoch 95/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3930 - accuracy: 0.9136
# Epoch 96/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3837 - accuracy: 0.9136
# Epoch 97/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3753 - accuracy: 0.9383
# Epoch 98/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3661 - accuracy: 0.9383
# Epoch 99/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3577 - accuracy: 0.9506
# Epoch 100/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3506 - accuracy: 0.9506
# Epoch 101/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3417 - accuracy: 0.9506
# Epoch 102/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3331 - accuracy: 0.9506
# Epoch 103/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3264 - accuracy: 0.9506
# Epoch 104/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3195 - accuracy: 0.9506
# Epoch 105/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3132 - accuracy: 0.9506
# Epoch 106/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3055 - accuracy: 0.9506
# Epoch 107/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.9506
# Epoch 108/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2915 - accuracy: 0.9630
# Epoch 109/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2865 - accuracy: 0.9630
# Epoch 110/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2807 - accuracy: 0.9630
# Epoch 111/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2756 - accuracy: 0.9506
# Epoch 112/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2697 - accuracy: 0.9506
# Epoch 113/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2629 - accuracy: 0.9630
# Epoch 114/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2567 - accuracy: 0.9630
# Epoch 115/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2524 - accuracy: 0.9753
# Epoch 116/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2461 - accuracy: 0.9630
# Epoch 117/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2408 - accuracy: 0.9630
# Epoch 118/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2375 - accuracy: 0.9630
# Epoch 119/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2319 - accuracy: 0.9630
# Epoch 120/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2266 - accuracy: 0.9630
# Epoch 121/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2239 - accuracy: 0.9630
# Epoch 122/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2197 - accuracy: 0.9753
# Epoch 123/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2139 - accuracy: 0.9630
# Epoch 124/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2093 - accuracy: 0.9630
# Epoch 125/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2066 - accuracy: 0.9753
# Epoch 126/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2020 - accuracy: 0.9877
# Epoch 127/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1976 - accuracy: 0.9753
# Epoch 128/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1935 - accuracy: 0.9753
# Epoch 129/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1910 - accuracy: 0.9753
# Epoch 130/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1859 - accuracy: 0.9877
# Epoch 131/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9877
# Epoch 132/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1802 - accuracy: 0.9877
# Epoch 133/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1757 - accuracy: 0.9877
# Epoch 134/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.9877
# Epoch 135/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1697 - accuracy: 0.9877
# Epoch 136/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1668 - accuracy: 1.0000
# Epoch 137/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9877
# Epoch 138/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1601 - accuracy: 0.9877
# Epoch 139/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1576 - accuracy: 0.9877
# Epoch 140/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1544 - accuracy: 0.9877
# Epoch 141/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1513 - accuracy: 1.0000
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1491 - accuracy: 1.0000
# Epoch 143/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1456 - accuracy: 1.0000
# Epoch 144/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1431 - accuracy: 1.0000
# Epoch 145/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1413 - accuracy: 1.0000
# Epoch 146/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1383 - accuracy: 1.0000
# Epoch 147/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1353 - accuracy: 1.0000
# Epoch 148/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 1.0000
# Epoch 149/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1309 - accuracy: 1.0000
# Epoch 150/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1286 - accuracy: 1.0000
# Epoch 151/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1261 - accuracy: 1.0000
# Epoch 152/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1239 - accuracy: 1.0000
# Epoch 153/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1215 - accuracy: 1.0000
# Epoch 154/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1194 - accuracy: 1.0000
# Epoch 155/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1176 - accuracy: 1.0000
# Epoch 156/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1162 - accuracy: 1.0000
# Epoch 157/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1139 - accuracy: 1.0000
# Epoch 158/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1115 - accuracy: 1.0000
# Epoch 159/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1097 - accuracy: 1.0000
# Epoch 160/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1082 - accuracy: 1.0000
# Epoch 161/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1061 - accuracy: 1.0000
# Epoch 162/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1042 - accuracy: 1.0000
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1028 - accuracy: 1.0000
# Epoch 164/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1019 - accuracy: 1.0000
# Epoch 165/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0999 - accuracy: 1.0000
# Epoch 166/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0986 - accuracy: 1.0000
# Epoch 167/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0968 - accuracy: 1.0000
# Epoch 168/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0949 - accuracy: 1.0000
# Epoch 169/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0935 - accuracy: 1.0000
# Epoch 170/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 171/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0902 - accuracy: 1.0000
# Epoch 172/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0889 - accuracy: 1.0000
# Epoch 173/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0879 - accuracy: 1.0000
# Epoch 174/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 175/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0848 - accuracy: 1.0000
# Epoch 176/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0838 - accuracy: 1.0000
# Epoch 177/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0830 - accuracy: 1.0000
# Epoch 178/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0811 - accuracy: 1.0000
# Epoch 179/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0804 - accuracy: 1.0000
# Epoch 180/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0787 - accuracy: 1.0000
# Epoch 181/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 1.0000
# Epoch 182/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 183/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0753 - accuracy: 1.0000
# Epoch 184/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 185/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 1.0000
# Epoch 186/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 187/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 188/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0702 - accuracy: 1.0000
# Epoch 189/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0691 - accuracy: 1.0000
# Epoch 190/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 191/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 192/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 193/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 194/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0654 - accuracy: 1.0000
# Epoch 195/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 196/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 197/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 198/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 199/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 200/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 1.0000

# %%
#chatting
import random
while True:
  texts_p = []
  prediction_input = input('You : ')
  #removing punctuation and converting to lowercase
  prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
  prediction_input = ''.join(prediction_input)
  texts_p.append(prediction_input)
  #tokenizing and padding
  prediction_input = tokenizer.texts_to_sequences(texts_p)
  prediction_input = np.array(prediction_input).reshape(-1)
  prediction_input = pad_sequences([prediction_input],input_shape)
  #getting output from model
  output = model.predict(prediction_input)
  output = output.argmax()
  #finding the right tag and predicting
  response_tag = le.inverse_transform([output])[0]
  print("Going Merry : ",random.choice(responses[response_tag]))
  if response_tag == "goodbye":
    break
# Out:
# You : hi
# 1/1 [==============================] - 0s 340ms/step
# Going Merry :  ahoy!!
# You : how are you
# 1/1 [==============================] - 0s 17ms/step
# Going Merry :  Yeah Fine, nothing much going on in my life
# You : ok
# 1/1 [==============================] - 0s 17ms/step
# Going Merry :  Hello my friend, How can I help you ?
# You : how do i join the pirates ?
# 1/1 [==============================] - 0s 21ms/step
# Going Merry :  contact the closest straw hat center from your location
